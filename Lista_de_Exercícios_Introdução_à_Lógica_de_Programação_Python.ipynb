# %% [markdown]
# <a href="https://colab.research.google.com/github/bhhhh10323/Atividades-pontuadas/blob/main/Lista_de_Exerc%C3%ADcios_Introdu%C3%A7%C3%A3o_%C3%A0_L%C3%B3gica_de_Programa%C3%A7%C3%A3o_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <html>
#   <body>
#     <header></header>
#         <CENTER>
#           <img src="https://docentes.uvv.br/Content/img/logo-uvv.png" alt="UVV-LOGO" style = width="100px"; height="100px">
#         </CENTER>
#         <CENTER>
#           <b>
#             <font size="5">FUNDAMENTOS DE TECNOLOGIA DA
# COMPUTAÇÃO
#           </b>
#           </CENTER>
#         <CENTER><b>Introdução à Lógica de Programação - Python</b></CENTER>
#         <CENTER><b>Lista de Exercício</b></CENTER><br/>
#         </font>

# %% [markdown]
# # EXERCÍCIO 1:

# %% [markdown]
# Escreva um algoritmo em **Python** para cada item a seguir:

# %% [markdown]
# **Lista de Exercício**: [Clique Aqui!](https://drive.google.com/file/d/1NnyD5D5m2JukWcjyohT-sBXZ_zpNc2hR/view?usp=sharing)

# %% [markdown]
# ## LETRA A

# %%
try:
    xA = float(input('COORDENADA X - PONTO A: '))
    yA = float(input('COORDENADA Y - PONTO A: '))
    xB = float(input('COORDENADA X - PONTO B: '))
    yB = float(input('COORDENADA Y - PONTO B: '))
    D = ((xB - xA) ** 2 + (yB - yA) ** 2) ** (1 / 2)
    print(f'DISTÂNCIA: A(xA, yA) e B(xB, yB) = A({xA: .1f}, {yA: .1f}), B({xB: .1f}, {yB: .1f}) = {D: .1f}')
    except Exception as ERRO_EXCECAO:
    print(f'Erro de exceção: {ERRO_EXCECAO}')

# %% [markdown]
# ## LETRA B

# %% [markdown]
# ## LETRA C

# %% [markdown]
# ## LETRA D

# %% [markdown]
# ## LETRA E

# %% [markdown]
# ## LETRA F

# %% [markdown]
# ## LETRA G

# %% [markdown]
# ## LETRA H

# %% [markdown]
# ## LETRA I

# %% [markdown]
# ## LETRA J

# %% [markdown]
# ## LETRA K

# %% [markdown]
# ## LETRA L

# %% [markdown]
# # EXERCÍCIO 2:

# %% [markdown]
# Faça o algoritmo gráfico - **FLUXOGRAMA DE DADOS: Padrão ANSI** para cada item a seguir:

# %% [markdown]
# ## LETRA A

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## LETRA B

# %% [markdown]
# ![Captura de Tela 2026-03-10 às 06.13.24.png](data:image/png;base64,...)

# %% [markdown]
# ## LETRA C

# %% [markdown]
# ![Captura de Tela 2026-03-10 às 06.14.48.png](data:image/png;base64,...)

# %% [markdown]
# #**OBRIGATÓRIO**: CONVERTER IPYNB para PDF:

# %% [markdown]
# **PASSO A PASSO:**
#
# 1.   Fazer o download do seu IPYNB.
# 2.   Fazer o upload do seu IPYNB para área temporária: content.
# 3.   Rodar o código abaixo com **output.ipynb**: Gerar um **HTML**.
# 4.   Fazer o download do seu HTML e abrir em um Browser qualquer.
# 3.   Imprimir a página **HTML em PDF**. Pronto (UFA)::: 😅!
#
# **MOTIVO:** Seus Gráficos, Imagens, Códigos Python e Células **NÃO** sairão **" CORTADOS "** de uma página para outra.

# %%
# %%shell
# jupyter nbconvert --to html /content/out.ipynb
